# %%
import numpy as np

# %%
a = np.array([1,2,3],dtype='int16')
b= np.array([2,6,7])
print(a*b)
# Out:
# [ 2 12 21]

# %%
c= np.array([[2.0,8.0,9.0],[10.0,11.0,18.0]])
print(c)
# Out:
# [[ 2.  8.  9.]
#  [10. 11. 18.]]

# %%
#get dimension
c.ndim
# Out:
# 2

# %%
# get shape
c.shape
# Out:
# (2, 3)

# %%
a.dtype
# Out:
# dtype('int16')

# %%
a= np.array([[2,4,5,6,7],[8,90,88,91,100]])
print(a)
# Out:
# [[  2   4   5   6   7]
#  [  8  90  88  91 100]]

# %%
a[1,-1]
# Out:
# 100

# %%
a[1,3]
# Out:
# 91

# %%
a[0,:]
# Out:
# array([2, 4, 5, 6, 7])

# %%
a[:,3]
# Out:
# array([ 6, 91])

# %%
a[0,1:4:2]
# Out:
# array([4, 6])

# %%
b = np.array([[[1,2],[3,4]],[[5,6],[7,8]]])
print(b)
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]
